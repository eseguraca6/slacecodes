# %%
# %run '/Users/eseguraca.6/Desktop/SLACfiles/slacecodes/utilities.ipynb'


c_pwd = Popen(["pwd"], stdout=PIPE, stderr=PIPE)

c_p = c_pwd.communicate()[0].decode('utf-8').rstrip()
print(c_p)

f = data_pathfiles_generator(c_p)

fnames = filename_generator(c_p)

data_arr = data_generator(f)

print(fnames)
plot_generator(data_arr, 2, 3, 20, 20, 0.95, 20, 15, 15,'x', 'irradiance', 'test new lens at f=6200', fnames, 'tf1600')

waist = np.multiply(2, fit_parameter_extractor(gaussian, data_arr)[2])

print(waist)

fl = 6200
step = np.divide(fl,2)
fmax = 2.5*fl
exp_x = np.arange(0,fmax,step)
print(exp_x)

f = plt.figure(figsize=(20,20))
f0 = f.add_subplot(111)

waist[1], waist[0] = waist[0], waist[1]
print(waist)
waist[2], waist[3] = waist[3], waist[2]
print(waist)
print(lens_waist_size(6200, 5, 600,6200))
numx = np.arange(0, fmax, 0.01)
numw = lens_waist_size(numx, 5,600,6200)
print(numw)
f0.scatter(exp_x, waist)
f0.plot(numx, numw, linestyle = ':', color = 'green')
#f0.plot(numx, numw)
# Out:
# /Users/eseguraca.6/Desktop/SLACfiles/slacecodes/enrique_lensmaker/f6200/nf6200
# ['run0.5f', 'run0', 'run1.5f', 'run1f', 'run2f']
# [ 2.50425993  5.00000022  2.44122862  0.23892791  4.85328531]
# [     0.   3100.   6200.   9300.  12400.]
# [ 5.00000022  2.50425993  2.44122862  0.23892791  4.85328531]
# [ 5.00000022  2.50425993  0.23892791  2.44122862  4.85328531]
# 0.236822555321
# [ 5.          4.99999194  4.99998387 ...,  7.52330822  7.52331629
#   7.52332435]

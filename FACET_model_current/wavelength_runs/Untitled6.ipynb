# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.optimize import curve_fit

pos = [0] #start

pos.append(pos[-1]+541) #m1
pos.append(pos[-1]+27) #l1

for i in range(0,3): #drifts 
    pos.append(pos[-1]+517)

pos.append(pos[-1]+517) #m2
pos.append(pos[-1]+100) #l2

for i in range(0,3):
    pos.append(pos[-1]+770.5)

pos.append(pos[-1]+770.5) #m3


for i in range(0,3):
    pos.append(pos[-1]+1530.25)

pos.append(pos[-1]+1530.25) #m4


for i in range(0,3):
    pos.append(pos[-1]+503.25)
    
pos.append(pos[-1]+503.25) #l3
pos.append(pos[-1]+381.7) #m5

for i in range(0,3):
    pos.append(pos[-1]+2934.575)

pos.append(pos[-1]+2934.575) #m6
pos.append(pos[-1]+381.7) #l4

for i in range(0,3):
    pos.append(pos[-1]+472.5)
    
print(len(pos))
pos_2m = []
pos_2m.append(0)
for i in range(1, len(pos)):
    pos_2m.append(pos[i]+2000)
######

saph_1_2000_ft = np.loadtxt('800_1_2000ft.csv')
saph_1_541_ft = np.loadtxt('800_1_541ft.csv')


saph_5_2000_ft = np.loadtxt('800_5_2000ft.csv')
saph_5_541_ft = np.loadtxt('800_5_541ft.csv')

hene_1_2000_ft = np.loadtxt('527_1_2000ft.csv')
hene_1_541_ft = np.loadtxt('527_1_541ft.csv')


hene_5_2000_ft = np.loadtxt('527_5_2000ft.csv')
hene_5_541_ft = np.loadtxt('527_5_541ft.csv')



saph= plt.figure(figsize=(10,10))
saphos = saph.add_subplot(111)
saphos.scatter(pos_2m, saph_1_2000_ft, marker = 'o', color ='red', label = 'Ti:Saph 2m away ($w_{0} = 1mm$)', s=30)
saphos.plot(pos_2m, saph_1_2000_ft, linestyle = '--', color = 'blue')



saphos.scatter(pos, saph_1_541_ft, marker = 'p', color ='green', label = 'Ti:Saph 1f away ($w_{0} = 1mm$)', s=50)
saphos.plot(pos, saph_1_541_ft, linestyle = ':', color = 'red')

labels = ['$L_{1}$','$L_2$', '$M_3$', '$M_4$', '$L_3$', '$M_5$', '$M_6$','$L_4$' ]
x = pos
y = saph_1_541_ft

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=15)

x = pos_2m
y = saph_1_2000_ft

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=15)

plt.tight_layout()

saphos.set_xlabel('Position Along Transport(mm)')
saphos.set_ylabel('Beam Size (mm)')


saphos.legend(loc = 'lower right')
saph.suptitle('Ti:Saph Beam Propagation in FACET-II Laser Transport', fontsize=20)

saph.tight_layout()
saph.subplots_adjust(top = 0.95)
# Out:
# 29

# %%
saph= plt.figure(figsize=(10,10))
saphos = saph.add_subplot(111)
saphos.scatter(pos_2m, saph_5_2000_ft, marker = 'o', color ='red', label = 'Ti:Saph 2m away ($w_{0} = 5mm$)', s=30)
saphos.plot(pos_2m, saph_5_2000_ft, linestyle = '--', color = 'green')



saphos.scatter(pos, saph_5_541_ft, marker = 'p', color ='orange', label = 'Ti:Saph 1f away ($w_{0} = 5mm$)', s=50)
saphos.plot(pos, saph_5_541_ft, linestyle = ':', color = 'red')

labels = ['$L_{1}$','$L_2$', '$M_3$', '$M_4$', '$L_3$', '$M_5$', '$M_6$','$L_4$' ]
x = pos
y = saph_5_541_ft

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=15)



plt.tight_layout()

saphos.set_xlabel('Position Along Transport(mm)')
saphos.set_ylabel('Beam Size (mm)')


saphos.legend(loc = 'lower right')
saph.suptitle('Ti:Saph Beam Propagation in FACET-II Laser Transport', fontsize=20)

saph.tight_layout()
saph.subplots_adjust(top = 0.95)

# %%
###############################

hene= plt.figure(figsize=(10,10))
henesos = hene.add_subplot(111)
henesos.scatter(pos_2m, hene_1_2000_ft, marker = 'D', color ='maroon', label = 'He:Ne 2m away ($w_{0} =1mm$)', s=30)
henesos.plot(pos_2m, hene_1_2000_ft, linestyle = ':', color = 'salmon')



henesos.scatter(pos, hene_1_541_ft, marker = 'H', color ='green', label = 'He:Ne 1f away ($w_{0} = 1mm$)', s=50)
henesos.plot(pos, hene_1_541_ft, linestyle = '-.', color = 'red')

labels = ['$L_{1}$','$L_2$', '$M_3$', '$M_4$', '$L_3$', '$M_5$', '$M_6$','$L_4$' ]
x = pos
y = hene_1_541_ft

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=15)

x = pos_2m
y = hene_1_2000_ft

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=15)



henesos.set_xlabel('Position Along Transport(mm)')
henesos.set_ylabel('Beam Size (mm)')

henesos.legend(loc = 'lower right')
hene.suptitle('He:Ne Beam Propagation in FACET-II Laser Transport', fontsize=20)

hene.tight_layout()
hene.subplots_adjust(top = 0.95)

# %%
###############################

hene= plt.figure(figsize=(10,10))
henesos = hene.add_subplot(111)
henesos.scatter(pos_2m, hene_5_2000_ft, marker = 'D', color ='magenta', label = 'He:Ne 2m away ($w_{0} =5mm$)', s=30)
henesos.plot(pos_2m, hene_5_2000_ft, linestyle = ':', color = 'cyan')



henesos.scatter(pos, hene_5_2000_ft, marker = 'H', color ='salmon', label = 'He:Ne 1f away ($w_{0} = 5mm$)', s=50)
henesos.plot(pos, hene_5_2000_ft, linestyle = '-.', color = 'brown')

labels = ['$L_{1}$','$L_2$', '$M_3$', '$M_4$', '$L_3$', '$M_5$', '$M_6$','$L_4$' ]
x = pos
y = hene_5_541_ft

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=15)

x = pos_2m
y = hene_5_2000_ft

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=15)



henesos.set_xlabel('Position Along Transport(mm)')
henesos.set_ylabel('Beam Size (mm)')

henesos.legend(loc = 'lower right')
hene.suptitle('He:Ne Beam Propagation in FACET-II Laser Transport', fontsize=20)

hene.tight_layout()
hene.subplots_adjust(top = 0.95)

# %%
hene= plt.figure(figsize=(10,10))
henesos = hene.add_subplot(111)

henesos.scatter(pos,saph_1_541_ft, marker = 'D', color ='magenta', label = '($w_{0} =1mm$)', s=30)
henesos.plot(pos, saph_1_541_ft, linestyle = ':', color = 'cyan')



henesos.scatter(pos, saph_5_541_ft, marker = 'H', color ='salmon', label = '($w_{0} = 5mm$)', s=50)
henesos.plot(pos, saph_5_541_ft, linestyle = '-.', color = 'brown')

labels = ['$L_{1}$','$L_2$', '$M_3$', '$M_4$', '$L_3$', '$M_5$', '$M_6$','$L_4$' ]
x = pos
y = saph_5_541_ft

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=15)

x = pos
y = saph_1_541_ft

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=15)






henesos.set_xlabel('Position Along Transport(mm)', fontsize=20)
henesos.set_ylabel('Beam Size (mm)', fontsize=20)

henesos.legend(loc = 'lower right',  fontsize=10)
hene.suptitle('Ti:Saph Beam Propagation in FACET-II Laser Transport', fontsize=25)

hene.tight_layout()
hene.subplots_adjust(top = 0.95)

# %%
hene= plt.figure(figsize=(10,10))
henesos = hene.add_subplot(111)

henesos.scatter(pos,hene_1_541_ft, marker = 'D', color ='green', label = '($w_{0} =1mm$)', s=30)
henesos.plot(pos, hene_1_541_ft, linestyle = ':', color = 'cyan')



henesos.scatter(pos, hene_5_541_ft, marker = 'H', color ='red', label = '($w_{0} = 5mm$)', s=50)
henesos.plot(pos, hene_5_541_ft, linestyle = '-.', color = 'brown')

labels = ['$L_{1}$','$L_2$', '$M_3$', '$M_4$', '$L_3$', '$M_5$', '$M_6$','$L_4$' ]
x = pos
y = hene_5_541_ft

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=15)

x = pos
y = hene_1_541_ft

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=15)






henesos.set_xlabel('Position Along Transport(mm)', fontsize=20)
henesos.set_ylabel('Beam Size (mm)', fontsize=20)

henesos.legend(loc = 'lower right',  fontsize=10)
hene.suptitle('Ti:Saph Beam Propagation in FACET-II Laser Transport', fontsize=25)

hene.tight_layout()
hene.subplots_adjust(top = 0.95)

# %%
hene= plt.figure(figsize=(25,11))
henesos = hene.add_subplot(111)

#henesos.scatter(pos,saph_1_541, marker = 'D', color ='magenta', label = '($w_{0} =1mm$)', s=30)
#henesos.plot(pos, saph_1_541, linestyle = ':', color = 'cyan')



henesos.scatter(pos, saph_5_541, marker = 'D', color ='red', label = '(Ti:Saph $w_{0} = 5mm$)', s=100)
henesos.plot(pos, saph_5_541, linestyle = '-.', color = 'blue')

henesos.scatter(pos, hene_5_541, marker = 'd', color ='green', label = '(He:Ne $w_{0} = 5mm$)', s=100)
henesos.plot(pos, hene_5_541, linestyle = '-.', color = 'orange')

henesos.scatter(pos, saph_1_541, marker = 'o', color ='blue', label = '(Ti:Saph $w_{0} = 1mm$)', s=100)
henesos.plot(pos, saph_1_541, linestyle = '-.', color = 'salmon')

henesos.scatter(pos, hene_1_541, marker = 'x', color ='crimson', label = '(He:Ne $w_{0} = 1mm$)', s=100)
henesos.plot(pos, hene_1_541, linestyle = '-.', color = 'teal')

labels = ['$L_{1}$','$L_2$', '$M_3$', '$M_4$', '$L_3$', '$M_5$', '$M_6$','$L_4$' ]
x = pos
y = saph_5_541

xp = [x[1], x[7] ,x[11],  x[15],x[19], x[20], x[24], x[25]]
yp = [y[1], y[7], y[11],  y[15],y[19],y[20],y[24], y[25]]
for l, xpt, ypt in zip(labels, xp,yp):
    plt.text(xpt,ypt,l, fontsize=25)


henesos.tick_params(axis = 'both', labelsize=20)



henesos.set_xlabel('Position Along Transport(mm)', fontsize=30)
henesos.set_ylabel('Beam Size (mm)', fontsize=30)

henesos.legend(loc = 'center right',  fontsize=20)
hene.suptitle('Ti:Saph Beam Propagation in FACET-II Laser Transport', fontsize=35)
#hene.subplots_adjust(top = 0.95)
hene.tight_layout()
hene.subplots_adjust(top = 0.85)

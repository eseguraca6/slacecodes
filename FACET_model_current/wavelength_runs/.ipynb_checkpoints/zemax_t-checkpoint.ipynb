# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
TiSaph_5_optics = 'tisaph_5mm_20mm_optics.csv'

tisaph_5 = pd.read_csv(TiSaph_5_optics)

plt.plot(tisaph_5, marker='o')

# %%
pos = [0] #s
pos.append(pos[-1]+541) #l1
pos.append(pos[-1]+27) #m1

for i in range(0,4):
    pos.append(pos[-1]+517)

pos.append(pos[-1]) #m2
pos.append(pos[-1]+100) #l2 

for i in range(0,4):
    pos.append(pos[-1]+770.5)

pos.append(pos[-1]) #m3

for i in range(0,4):
    pos.append(pos[-1]+1530.25)
    
pos.append(pos[-1]) #m4

for i in range(0,4):
    pos.append(pos[-1]+503.075)

pos.append(pos[-1]) #l3
pos.append(pos[-1]+381.7)#m5

for i in range(0,4):
    pos.append(pos[-1]+2934.575)

pos.append(pos[-1]) #m6
pos.append(pos[-1]+381.7)#l4

for i in range(0,4):
    pos.append(pos[-1]+472.5)

for i in range(len(pos)):
    print(i, pos[i])
# Out:
# 0 0
# 1 541
# 2 568
# 3 1085
# 4 1602
# 5 2119
# 6 2636
# 7 2636
# 8 2736
# 9 3506.5
# 10 4277.0
# 11 5047.5
# 12 5818.0
# 13 5818.0
# 14 7348.25
# 15 8878.5
# 16 10408.75
# 17 11939.0
# 18 11939.0
# 19 12442.075
# 20 12945.150000000001
# 21 13448.225000000002
# 22 13951.300000000003
# 23 13951.300000000003
# 24 14333.000000000004
# 25 17267.575000000004
# 26 20202.150000000005
# 27 23136.725000000006
# 28 26071.300000000007
# 29 26071.300000000007
# 30 26453.000000000007
# 31 26925.500000000007
# 32 27398.000000000007
# 33 27870.500000000007
# 34 28343.000000000007

# %%
ti_5mm_20 = np.loadtxt('tisaph_5mm.csv')

plt.plot(pos, ti_5mm_20, marker = 'o')

# %%
import subprocess
from subprocess import PIPE, Popen
import sympy
from sympy import *
import numpy as np
init_printing(use_unicode=True)
from matplotlib import rc
import mpmath
import pandas as pd
import matplotlib.pylab as plt

pth = '/Users/eseguraca.6/Desktop/SLACfiles/slacecodes/raytracing'

ls_cmd = subprocess.Popen('ls',cwd=pth, stdout=PIPE, stderr=PIPE)

for line in ls_cmd.communicate():
    print(line.decode('utf-8'))
# Out:
# 10_0.00125394624_-0.00162634026.csv
# 11_0.000633398925_-0.000795976493.csv
# 12_0.000319841185_-0.000389357871.csv
# 13_0.000161455341_-0.00019034796.csv
# 14_8.14768328e-05_-9.30010617e-05.csv
# 15_4.11038405e-05_-4.54105805e-05.csv
# 16_2.07300354e-05_-2.21586793e-05.csv
# 17_1.04517696e-05_-1.08052705e-05.csv
# 18_5.26810496e-06_-5.26524582e-06.csv
# 1_0.582965629_-0.985495433.csv
# 2_0.293726517_-0.484859537.csv
# 3_0.148372953_-0.238318128.csv
# 4_0.075030615_-0.117059632.csv
# 5_0.0379552672_-0.0574668199.csv
# 6_0.0191998013_-0.028197283.csv
# 7_0.00971038047_-0.0138287782.csv
# 8_0.0049097016_-0.00677869967.csv
# 9_0.00248163479_-0.00332116895.csv
# Untitled.ipynb
# analysis of slope.ipynb
# gridmlm-1.430x1-0mmdecen.csv
# gridmlm-1.430x1-1mmdecen.csv
# m-l-m.CFG
# m-l-m.ZDA
# m-l-m.zmx
# m1m2--5-5-0.1.csv
# m1m2l1-nodecentering--1.5-1.5-0.01.csv
# m1m2l1-nodecenteringlens--1.5-1.5-0.1.csv
# m1m2l1-nodecenteringlensy--1.5-1.5-0.1.csv
# ...

# %%
t='/Users/eseguraca.6/Desktop/SLACfiles/slacecodes/raytracing/3_0.148372953_-0.238318128.csv'
data = pd.read_csv(t, delimiter='\t', encoding=('utf-16'), skiprows=14)

plt.imshow(data)
